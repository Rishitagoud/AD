# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishitagoud/AD/blob/main/day20(413).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#day20
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_wordcloud(text, output_filename):
    # Generate the WordCloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the WordCloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")

    # Save the WordCloud image
    wordcloud.to_file(output_filename)
    print(f"WordCloud saved as {output_filename}")

# Sample text
data_text = 'data science machine learning artificial intelligence'

# Generate and save WordCloud
#day20
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_wordcloud(text, output_filename):
    # Generate the WordCloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the WordCloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")

    # Save the WordCloud image
    wordcloud.to_file(output_filename)
    print(f"WordCloud saved as {output_filename}")

# Sample text
data_text = 'data science machine learning artificial intelligence'

# Generate and save WordCloud
generate_wordcloud(data_text, 'wordcloud.png')
# Out:
# WordCloud saved as wordcloud.png
